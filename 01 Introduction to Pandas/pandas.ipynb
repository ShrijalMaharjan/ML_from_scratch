# %% [markdown]
# <a href="https://colab.research.google.com/github/ShrijalMaharjan/ML_from_scratch/blob/main/01%20Introduction%20to%20Pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pandas
#
# Data Preprocessing in Machine Learning using Pandas.
#
# Data preprocessing is required tasks for cleaning the data and making it suitable for a machine learning model which is also increase the accuracy and effiency of a machine learning model.
#
# Pandas is an open source Python package that is most widely used for data science/ data analysis and machine learning tasks. It is built on top of another package named Numpy, which provides support for multi-dimensional arrays. Preprocessing is the process of doing a pre-analysis of data, in order to transform them into a standard and normalized format.
#
# Preprocessing involves the following aspects:
#
#   - missing values
#   - data standardization
#   - data normalization
#   - data mining

# %%
import pandas as pd

# %%
data = {
    "cars" : ["BMW", "Honda", "Suzuki", "BYD"],
    "models" : ["2007", "2009", "2008", "2023"],
    "passenger" : ["5", "5", "6", "7"]
}
#print(data)
data
# Out:
# {'cars': ['BMW', 'Honda', 'Suzuki', 'BYD'],
#  'models': ['2007', '2009', '2008', '2023'],
#  'passenger': ['5', '5', '6', '7']}

# %%
# convert the data into dataframe
df = pd.DataFrame(data)
df
# Out:
#      cars models passenger
# 0     BMW   2007         5
# 1   Honda   2009         5
# 2  Suzuki   2008         6
# 3     BYD   2023         7

# %%
# Save the file as csv file
df.to_csv("car_data.csv")

# %%
df.to_csv("/content/drive/MyDrive/ML Training/6th Sem/car_data.csv")

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
# Pandas Series
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
myvar
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
# Create labels in pandas with index
a = [1, 7, 2]
myvar = pd.Series(a, index=["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
print(myvar["x"])
# Out:
# 1

# %%
# task: Create a dataframe named df, with data calories and duration.
import pandas as pd
data = {
    "calories" : ["50", "100", "150"],
    "duration" : ["5", "10", "15"]
}
df = pd.DataFrame(data)
df
# Out:
#   calories duration
# 0       50        5
# 1      100       10
# 2      150       15

# %%
df.loc[[0,1]]
# Out:
#   calories duration
# 0       50        5
# 1      100       10

# %%
import pandas as pd
data = {
    "calories" : ["50", "100", "150"],
    "duration" : ["5", "10", "15"]
}
df = pd.DataFrame(data, index = ["Day1", "Day2", "Day3"])
df
# Out:
#      calories duration
# Day1       50        5
# Day2      100       10
# Day3      150       15

# %%
df.loc["Day2"]
# Out:
# calories    100
# duration     10
# Name: Day2, dtype: object
